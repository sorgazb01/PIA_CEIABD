# %% [markdown]
# # Ejercicios Avanzados Estructuras de Datos --> Listas, Tuplas y Diccionarios
#
# ![](https://drive.google.com/uc?id=1maraWVAXZ2BHkOfxFe8YX_SzItGqspvE)

# %% [markdown]
# ## Ejercicio 1
# **Gestión de datos meteorológicos**
#
# Un sistema de predicción del tiempo recibe datos diarios en forma de tuplas (fecha, temperatura, humedad). Se necesita un programa que recorra una lista de estos datos y calcule:
#
# Calcula:
#
# * El promedio de la temperatura.
# * Encuentra el día con mayor humedad, pero si la temperatura promedio supera 22°C, ignora los días con una humedad inferior al 80% para determinar el día con mayor humedad.

# %%
#Datos de pruebas:
[
    ('2024-11-01', 20.1, 81),
    ('2024-11-02', 23.5, 78),
    ('2024-11-03', 22.1, 68),
    ('2024-11-04', 24.0, 74),
    ('2024-11-05', 19.6, 80),
    ('2024-11-06', 18.3, 87),
    ('2024-11-07', 22.3, 87),
    ('2024-11-08', 23.7, 69),
    ('2024-11-09', 19.1, 84),
    ('2024-11-10', 25.4, 82),
    ('2024-11-11', 22.3, 82),
    ('2024-11-12', 18.8, 67),
    ('2024-11-13', 21.2, 66),
    ('2024-11-14', 25.4, 72),
    ('2024-11-15', 24.4, 67),
    ('2024-11-16', 19.4, 81),
    ('2024-11-17', 19.4, 84),
    ('2024-11-18', 20.2, 67),
    ('2024-11-19', 24.1, 75),
    ('2024-11-20', 22.7, 79),
    ('2024-11-21', 18.8, 80),
    ('2024-11-22', 19.4, 75),
    ('2024-11-23', 21.4, 89),
    ('2024-11-24', 25.6, 73),
    ('2024-11-25', 19.4, 85),
    ('2024-11-26', 21.1, 83),
    ('2024-11-27', 24.4, 80),
    ('2024-11-28', 19.6, 69),
    ('2024-11-29', 21.8, 90),
    ('2024-11-30', 24.9, 72)
]
# Out:
# [('2024-11-01', 20.1, 81),
#  ('2024-11-02', 23.5, 78),
#  ('2024-11-03', 22.1, 68),
#  ('2024-11-04', 24.0, 74),
#  ('2024-11-05', 19.6, 80),
#  ('2024-11-06', 18.3, 87),
#  ('2024-11-07', 22.3, 87),
#  ('2024-11-08', 23.7, 69),
#  ('2024-11-09', 19.1, 84),
#  ('2024-11-10', 25.4, 82),
#  ('2024-11-11', 22.3, 82),
#  ('2024-11-12', 18.8, 67),
#  ('2024-11-13', 21.2, 66),
#  ('2024-11-14', 25.4, 72),
#  ('2024-11-15', 24.4, 67),
#  ('2024-11-16', 19.4, 81),
#  ('2024-11-17', 19.4, 84),
#  ('2024-11-18', 20.2, 67),
#  ('2024-11-19', 24.1, 75),
#  ('2024-11-20', 22.7, 79),
#  ('2024-11-21', 18.8, 80),
#  ('2024-11-22', 19.4, 75),
#  ('2024-11-23', 21.4, 89),
#  ('2024-11-24', 25.6, 73),
#  ('2024-11-25', 19.4, 85),
#  ('2024-11-26', 21.1, 83),
#  ('2024-11-27', 24.4, 80),
#  ('2024-11-28', 19.6, 69),
#  ('2024-11-29', 21.8, 90),
#  ('2024-11-30', 24.9, 72)]

# %%
#Solución:

# %% [markdown]
# ---
# ## Ejercicio 2
#
# **Normalización de datos de usuarios**
#
# Una aplicación almacena información de usuarios en un diccionario donde las **claves son los IDs y los valores son tuplas con la edad y el ingreso mensual** de cada usuario. Escribe un programa que recorra el diccionario y cree una nueva lista de tuplas, donde la edad e ingreso mensual estén normalizados entre 0 y 1 con respecto al máximo encontrado en cada categoría.
#
#
# **Nota sobre la normalización de datos:**
#
# * La **normalización** es un proceso matemático utilizado para escalar valores dentro de un rango común, generalmente entre 0 y 1.
# * Este proceso asegura que todos los valores estén representados proporcionalmente entre 0 y 1, preservando las relaciones relativas entre ellos.
#
#
# La fórmula básica para normalizar un valor \( x \) es:
#
# $$
# x_{\text{normalizado}} = \frac{x - x_{\text{mín}}}{x_{\text{máx}} - x_{\text{mín}}}
# $$
#
# Donde:
# - $x$ es el valor original.
# - $x_{\text{mín}}$ es el valor mínimo en la serie de datos.
# - $x_{\text{máx}}$ es el valor máximo en la serie de datos.
#
# En situaciones donde no hay valores negativos, la formula sería:
#
# $$
# x_{\text{normalizado}} = \frac{x}{x_{\text{máx}}}
# $$
#
# Esta última fórmula es válida si todos los valores son positivos y la escala de interés se centra en el máximo.

# %%
#Datos de Pruebas
usuarios = {
    1: (25, 3000),
    2: (None, 4500),  
    3: (22, None),    
    4: (30, 3800),
    5: (None, None),  
    6: (27, 5000),
}

# %%
#Solución:

# %% [markdown]
# ---
# ## Ejercicio 3
#
# **Registro de fallos en servidores**
#
# Una lista contiene diccionarios con registros de fallos en servidores. Cada diccionario tiene las claves servidor, tipo_fallo y frecuencia. Escribe un programa que:
# 1. Cree un diccionario donde las claves sean los servidores y los valores sean listas con los tipos de fallo ordenados por frecuencia.
# 2. Crea una lista de servidores con más de 3 tipos de fallos distintos. Si no existen tales servidores, retorna una lista vacía.

# %%
# Datos de pruebas:
datos_fallos = [
    {'servidor': 'C', 'tipo_fallo': 'CPU', 'frecuencia': 7},
    {'servidor': 'D', 'tipo_fallo': 'Fuente de poder', 'frecuencia': 9},
    {'servidor': 'C', 'tipo_fallo': 'Fuente de poder', 'frecuencia': 3},
    {'servidor': 'C', 'tipo_fallo': 'Red', 'frecuencia': 10},
    {'servidor': 'C', 'tipo_fallo': 'Memoria', 'frecuencia': 9},
    {'servidor': 'B', 'tipo_fallo': 'Fuente de poder', 'frecuencia': 8},
    {'servidor': 'E', 'tipo_fallo': 'Fuente de poder', 'frecuencia': 10},
    {'servidor': 'C', 'tipo_fallo': 'Red', 'frecuencia': 10},
    {'servidor': 'A', 'tipo_fallo': 'Fuente de poder', 'frecuencia': 10},
    {'servidor': 'B', 'tipo_fallo': 'Disco', 'frecuencia': 7},
    {'servidor': 'D', 'tipo_fallo': 'Fuente de poder', 'frecuencia': 10},
    {'servidor': 'A', 'tipo_fallo': 'Red', 'frecuencia': 3},
    {'servidor': 'A', 'tipo_fallo': 'Fuente de poder', 'frecuencia': 5},
    {'servidor': 'C', 'tipo_fallo': 'CPU', 'frecuencia': 1},
    {'servidor': 'E', 'tipo_fallo': 'Fuente de poder', 'frecuencia': 7},
    {'servidor': 'B', 'tipo_fallo': 'Red', 'frecuencia': 4},
    {'servidor': 'A', 'tipo_fallo': 'Red', 'frecuencia': 10},
    {'servidor': 'C', 'tipo_fallo': 'Disco', 'frecuencia': 5},
    {'servidor': 'E', 'tipo_fallo': 'Fuente de poder', 'frecuencia': 9},
    {'servidor': 'C', 'tipo_fallo': 'Fuente de poder', 'frecuencia': 7},
    {'servidor': 'E', 'tipo_fallo': 'CPU', 'frecuencia': 10},
    {'servidor': 'A', 'tipo_fallo': 'CPU', 'frecuencia': 3},
    {'servidor': 'B', 'tipo_fallo': 'Red', 'frecuencia': 9},
    {'servidor': 'D', 'tipo_fallo': 'Disco', 'frecuencia': 1},
    {'servidor': 'C', 'tipo_fallo': 'Red', 'frecuencia': 5},
    {'servidor': 'A', 'tipo_fallo': 'Disco', 'frecuencia': 5},
    {'servidor': 'E', 'tipo_fallo': 'CPU', 'frecuencia': 8},
    {'servidor': 'C', 'tipo_fallo': 'Fuente de poder', 'frecuencia': 7},
    {'servidor': 'A', 'tipo_fallo': 'Fuente de poder', 'frecuencia': 6},
    {'servidor': 'C', 'tipo_fallo': 'Fuente de poder', 'frecuencia': 7},
    {'servidor': 'A', 'tipo_fallo': 'Red', 'frecuencia': 10},
    {'servidor': 'A', 'tipo_fallo': 'Memoria', 'frecuencia': 2},
    {'servidor': 'B', 'tipo_fallo': 'Fuente de poder', 'frecuencia': 1},
    {'servidor': 'E', 'tipo_fallo': 'Fuente de poder', 'frecuencia': 8},
    {'servidor': 'D', 'tipo_fallo': 'Fuente de poder', 'frecuencia': 7},
    {'servidor': 'A', 'tipo_fallo': 'Disco', 'frecuencia': 7},
    {'servidor': 'E', 'tipo_fallo': 'CPU', 'frecuencia': 5},
    {'servidor': 'E', 'tipo_fallo': 'Red', 'frecuencia': 6},
    {'servidor': 'B', 'tipo_fallo': 'Red', 'frecuencia': 10},
    {'servidor': 'D', 'tipo_fallo': 'Memoria', 'frecuencia': 1},
    {'servidor': 'A', 'tipo_fallo': 'CPU', 'frecuencia': 3},
    {'servidor': 'C', 'tipo_fallo': 'Memoria', 'frecuencia': 1},
    {'servidor': 'E', 'tipo_fallo': 'Fuente de poder', 'frecuencia': 8},
    {'servidor': 'D', 'tipo_fallo': 'Disco', 'frecuencia': 9},
    {'servidor': 'C', 'tipo_fallo': 'Red', 'frecuencia': 5},
    {'servidor': 'E', 'tipo_fallo': 'Memoria', 'frecuencia': 9},
    {'servidor': 'C', 'tipo_fallo': 'Red', 'frecuencia': 10},
    {'servidor': 'B', 'tipo_fallo': 'Disco', 'frecuencia': 2},
    {'servidor': 'B', 'tipo_fallo': 'Memoria', 'frecuencia': 6},
    {'servidor': 'B', 'tipo_fallo': 'Memoria', 'frecuencia': 5}
]

# %%
#Solución:

# %% [markdown]
# ---
# ## Ejercicio 4
#
# **Procesamiento de ventas por región**
#
# Una empresa tiene un diccionario donde las claves son regiones y los valores son listas de tuplas con información de ventas (producto, cantidad, precio_unitario).
#
# Escribe un programa que calcule:
# * El ingreso total por región y devuelva un nuevo diccionario con las regiones como claves y los ingresos como valores. Si en alguna región la venta total supera 10mil unidades monetarias:
#     *  Recalcula los ingresos considerando un **descuento del 10% sobre los productos cuyo precio unitario supere 50.**

# %%
#Datos de pruebas:
datos_ventas = {
    'Norte': [
        ('Producto1', 27, 13.79),
        ('Producto5', 2, 31.87),
        ('Producto5', 3, 74.2),
        ('Producto5', 43, 80.26),
        ('Producto2', 23, 74.13),
        ('Producto2', 29, 49.84)
    ],
    'Sur': [
        ('Producto2', 15, 44.02),
        ('Producto5', 12, 90.66),
        ('Producto1', 33, 18.45),
        ('Producto5', 1, 88.74),
        ('Producto5', 16, 15.71),
        ('Producto3', 49, 94.61),
        ('Producto1', 12, 45.9),
        ('Producto1', 17, 87.96),
        ('Producto3', 36, 50.98),
        ('Producto4', 18, 39.32)
    ],
    'Este': [
        ('Producto3', 43, 95.86),
        ('Producto4', 8, 65.2),
        ('Producto5', 8, 72.66),
        ('Producto2', 12, 73.69),
        ('Producto5', 3, 46.67),
        ('Producto5', 1, 85.29),
        ('Producto5', 21, 94.97),
        ('Producto3', 45, 92.51),
        ('Producto3', 50, 79.64),
        ('Producto3', 4, 24.18)
    ],
    'Oeste': [
        ('Producto3', 6, 14.02),
        ('Producto3', 47, 21.55),
        ('Producto4', 46, 32.02),
        ('Producto3', 45, 46.97),
        ('Producto5', 2, 30.75)
    ],
    'Centro': [
        ('Producto4', 41, 21.6),
        ('Producto3', 20, 64.34),
        ('Producto1', 36, 36.65),
        ('Producto3', 39, 17.97),
        ('Producto5', 8, 67.43),
        ('Producto2', 35, 11.5)
    ]
}

# %%
#Solución:

# %% [markdown]
# ---
#
# ## Ejercicio 5
#
# **Agrupación de resultados de modelos de IA**
#
# Una lista contiene los resultados de modelos de IA en varias pruebas, cada resultado es un diccionario con las claves modelo, prueba y puntuación.
#
# Escribe un programa que:
# 1. Agrupe las puntuaciones por modelo de aquellas cuya puntuación esté por encima del promedio global de todas las pruebas. Crea un nuevo diccionario donde las claves sean los nombres de los modelos y los valores sean listas con las puntuaciones de todas las pruebas.

# %%
#Datos de pruebas:
resultados_ia = [
    {'modelo': 'ModeloA', 'prueba': 'Prueba1', 'puntuación': 0.83},
    {'modelo': 'ModeloA', 'prueba': 'Prueba2', 'puntuación': 0.56},
    {'modelo': 'ModeloA', 'prueba': 'Prueba3', 'puntuación': 0.91},
    {'modelo': 'ModeloA', 'prueba': 'Prueba4', 'puntuación': 0.76},
    {'modelo': 'ModeloA', 'prueba': 'Prueba5', 'puntuación': 0.81},
    {'modelo': 'ModeloB', 'prueba': 'Prueba1', 'puntuación': 0.59},
    {'modelo': 'ModeloB', 'prueba': 'Prueba2', 'puntuación': 0.65},
    {'modelo': 'ModeloB', 'prueba': 'Prueba3', 'puntuación': 0.69},
    {'modelo': 'ModeloB', 'prueba': 'Prueba4', 'puntuación': 0.80},
    {'modelo': 'ModeloB', 'prueba': 'Prueba5', 'puntuación': 0.73},
    {'modelo': 'ModeloC', 'prueba': 'Prueba1', 'puntuación': 0.97},
    {'modelo': 'ModeloC', 'prueba': 'Prueba2', 'puntuación': 0.87},
    {'modelo': 'ModeloC', 'prueba': 'Prueba3', 'puntuación': 0.89},
    {'modelo': 'ModeloC', 'prueba': 'Prueba4', 'puntuación': 0.78},
    {'modelo': 'ModeloC', 'prueba': 'Prueba5', 'puntuación': 0.80},
    {'modelo': 'ModeloD', 'prueba': 'Prueba1', 'puntuación': 0.55},
    {'modelo': 'ModeloD', 'prueba': 'Prueba2', 'puntuación': 0.97},
    {'modelo': 'ModeloD', 'prueba': 'Prueba3', 'puntuación': 0.75},
    {'modelo': 'ModeloD', 'prueba': 'Prueba4', 'puntuación': 0.51},
    {'modelo': 'ModeloD', 'prueba': 'Prueba5', 'puntuación': 0.69},
    {'modelo': 'ModeloE', 'prueba': 'Prueba1', 'puntuación': 0.82},
    {'modelo': 'ModeloE', 'prueba': 'Prueba2', 'puntuación': 0.94},
    {'modelo': 'ModeloE', 'prueba': 'Prueba3', 'puntuación': 0.97},
    {'modelo': 'ModeloE', 'prueba': 'Prueba4', 'puntuación': 0.99},
    {'modelo': 'ModeloE', 'prueba': 'Prueba5', 'puntuación': 0.65},
]

# %%
#Solución:
