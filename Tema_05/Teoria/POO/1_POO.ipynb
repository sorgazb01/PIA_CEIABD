# %% [markdown]
# # Programación Orientada a Objetos

# %% [markdown]
# ## 1.⚡ Concepto de Programación Orientada a Objetos ⚡

# %% [markdown]
# * La programación orientada a objetos (POO) es un paradigma de programación que **se enfoca en la creación de "objetos" que contienen tanto datos como funcionalidad.**
#
#
# * Estos objetos están diseñados para **interactuar entre sí y trabajar juntos para resolver problemas complejos.**
#
#
# * En Python, **todo es un objeto, incluyendo los tipos de datos básicos como las cadenas y los números.**
#
#
# * Estos objetos se relacionan entre sí y se utilizan para **representar conceptos del mundo real en el código.**
#
#     * Un estudiante
#     * Un coche
#     * Un teléfono
#     * Una persona
#     * etc
#
#
# * Primer pilar de la POO: **los datos y las operaciones que pueden realizarse** con esos datos se agrupan en unidades lógicas llamadas:
#
#  ⭐ **OBJETOS.** ⭐
#
#
# Los otros dos pilares de la POO son la **herencia y el polimorfismo** que veremos más adelante.
#
#
# <font color='blue'>**Las principales ventajas de la POO son:**</font>
#
# 1. **Facilita la organización del código de una manera más clara y lógica,** lo que hace que sea más legible y comprensible.
#
#
# 2. **Reduce la cantidad de código** que se tiene que escribir y **facilita el mantenimiento del programa.**
#
#
# 3. La POO facilita el trabajo con colecciones de datos, ya que **permite tratar a cada objeto de manera individual.**
#
#
# 4. Permite hacer una mejor distinción entre la lógica de negocio y la interfaz de usuario, lo que **facilita el desarrollo de programas complejos.**
#
#
# 5. **Facilita el trabajo en equipo,** ya que cada miembro del equipo puede trabajar en una parte diferente del programa sin afectar el trabajo de los demás.

# %% [markdown]
# ### 1.1 Clases y Objetos
#
# Antes de entrar con la práctica vamos a aclarar algunos conceptos que, a veces, pueden llevarnos a confusión.
#
# A lo largo de este Notebook vamos a hablar mucho sobre **clases y objetos.** A menudo se utilizan como sinónimos **pero esto no es correcto.**
#
# **Diferencias entre clase y objeto:**
#
#
# * **La principal diferencia** entre una clase y un objeto es que <font color='blue'>**la clase es una plantilla o molde para crear objetos,**</font> mientras que <font color='green'>**el objeto es una instancia de esa clase que tiene sus propios atributos y métodos.**</font>
#
#
# * **Una clase** <font color='blue'>**define cómo debe ser un objeto,**</font> pero <font color='green'>**no contiene valores específicos.**</font>
#
#
# * **Un objeto,** en cambio, <font color='green'>**contiene valores concretos para sus atributos y puede ser manipulado mediante sus métodos.**</font>
#
#
# * Por ejemplo, si tenemos una clase "Persona" que tiene atributos "nombre" y "edad", **podemos crear dos objetos de esa clase que tengan diferentes valores para esos atributos.**

# %% [markdown]
# ---
#
# ## 2. 🥇**Clases (class)** 🥇
#
# **Los objetos con los mismos atributos y métodos se agrupan clases.**
#
# Las clases **definen los atributos y los métodos**, y por tanto, el **🔼comportamiento🔼** que tienen los objetos que pertenecen a esa clase.

# %% [markdown]
# ### 2.1. Atributos y Métodos.
#
# * Los atributos son variables que forman parte de una clase y **representan datos o información asociada a la clase.**
#
#
# * Los métodos, por otro lado, **son funciones que se definen dentro de una clase y que pueden ser utilizadas para realizar operaciones con los atributos de un objeto de esa clase.**
#
#
# * Una buena forma de diferenciarlos es recordar que **los atributos representan datos, mientras que los métodos representan acciones o comportamientos.**

# %% [markdown]
# ###  2.2🔧**Declaración de una CLASE**🔧
#
# Para declarar una clase en python, se utiliza la palabra reservada **class seguida del nombre de la clase y dos puntos**, de acuerdo a la siguiente sintaxis:
#
# **class nombre-clase:**
#
#      **atributos**
#
#      **métodos**
#
# * **Los atributos se definen igual que las variables mientras que los métodos se definen igual que las funciones.** Tanto unos como otros tienen que estar indentados por 4 espacios en el cuerpo de la clase.
#
#
#
# * ❗Los nombres de las clases **deben empezar con una letra mayúscula y usar notación CamelCase,** es decir, cada nueva palabra empieza con una mayúscula.❗
#
# Por ejemplo:

# %%
class MiClase:
    # Atributo
    mi_atributo = 5

    # Método
    def mi_metodo(self, arg1, arg2):
        # Aquí iría el código del método
        pass

# %% [markdown]
# ### 2.3. Atributos de Clase y de Instancia
#
# #### **Tenemos dos tipos de atributos:**
#
# 1. Los  que se crean **dentro del método __ init __** se conocen como ✅ **atributos de objeto/instancia.** ✅
#   *   Son propios de cada objeto y por tanto **pueden tomar valores distintos**
#
#
# 2. Los que se crean **fuera del método __ init __** se conocen como ✅ **atributos de la clase.** ✅
#     *   Son los mismos para cualquier objeto de la clase, **NO CAMBIAN DE VALOR**
#
#     * **Se definen después de la palabra reservada "class".**
#
#
#
# ❗ En general, **no deben usarse atributos de clase**, excepto para almacenar valores constantes. ❗

# %%
#DEFINICIÓN DE LA CLASE CIRCULO
class Circulo:
    pi = 3.14159                   # Atributo de clase, SERÁ UNA CONSTANTE
    def __init__(self, radio):
        self.radio = radio           # Atributo de instancia

# %% [markdown]
# ### 2.4 Constructores
#
# * El constructor es un **método especial en una clase que se llama automáticamente cuando se crea un objeto de esa clase.**
#
#
# * El constructor se llama "\__init__" y se utiliza para inicializar los atributos del objeto recién creado.
#
#
# * El constructor **siempre debe tener al menos un argumento, que se llama "self"** y que hace referencia al objeto
# que está siendo creado. Por ejemplo:

# %%
class MiClase:
    def __init__(self, valor_miatributo):
        # Inicializar atributos del objeto
        self.mi_atributo = valor_miatributo

# %% [markdown]
# #### 2.4.1 Definiendo Varios Constructores.
#
# **¿Puedo tener varios métodos para crear un objeto?**
#
# * Sí, en Python **se pueden tener varios constructores en una misma clase.**
#
#
# * Esto se logra mediante la sobrecarga de métodos, que **permite tener varias implementaciones del mismo método con diferentes argumentos.**
#
#
# * Cuando se quiere tener varios constructores, **se suele tener un constructor "principal" que tiene todos los argumentos necesarios para inicializar un objeto,** y luego otros constructores que llaman al constructor principal y le pasan valores por defecto para algunos de sus argumentos. De esta manera, se pueden proporcionar diferentes formas de crear un objeto de la clase. Por ejemplo:

# %%
class MiClase:
    def __init__(self, arg1, arg2, arg3):
        # Constructor principal
        # Inicializar atributos con los argumentos recibidos
        self.arg1 = arg1
        self.arg2 = arg2
        self.arg3 = arg3

    def __init__(self, arg1, arg2):
        # Constructor secundario que llama al constructor principal
        # Se asume que arg3 tiene un valor por defecto
        self.__init__(arg1, arg2, "Valor por defecto")

    def __init__(self):
        # Constructor secundario que llama al constructor principal
        # Se asumen valores por defecto para todos los argumentos
        self.__init__("Valor por defecto", "Valor por defecto", "Valor por defecto")

# %% [markdown]
# En este ejemplo, **se pueden crear objetos de la clase "MiClase" de tres maneras diferentes:** proporcionando todos los argumentos al constructor, proporcionando solo dos argumentos, o no proporcionando argumentos (en cuyo caso se usarán los valores por defecto).

# %% [markdown]
# ---
#
# ## 3. Creando Objetos - 🔧**Instanciación de clases**🔧
#
#
# * Llamamos instanciar a la acción de crear un objeto de una determinada clase.
#
# * Para crear o instanciar un objeto de una determinada clase se utiliza:
#
#   * **El nombre de la clase seguida de los parámetros necesarios para crear el objeto entre paréntesis.**
#
#
# * Cuando se crea un objeto de una clase se dice que el objeto ☝ **es una instancia de la clase.** ☝
#
#
# * Podemos tener **infinitos objetos instanciados** de una determinada clase.

# %%
class MiClase:
    def __init__(self, arg1, arg2):
        # Inicializar atributos del objeto
        print("Creando objeto MiClase")
        self.arg1 = arg1
        self.arg2 = arg2
        
    def mi_metodo(self):
        print("Llamando a Mi metodo")

# %%
# Crear un objeto de la clase "MiClase"
objeto = MiClase("Valor 1", "Valor 2")
# Out:
# Creando objeto MiClase

# %% [markdown]
# **Una vez creado el objeto, se pueden acceder a sus atributos y utilizar sus métodos mediante la notación "objeto.atributo" o "objeto.metodo()".**
#
# Por ejemplo:

# %%
# Acceder a un atributo del objeto
valor_atributo = objeto.arg1
print(valor_atributo)

# Llamar a un método del objeto
objeto.mi_metodo()
# Out:
# Valor 1
# Llamando a Mi metodo

# %% [markdown]
# ---
#
# ## 4. Métodos Mágicos
#
# * Los métodos mágicos **son métodos especiales que tienen una sintaxis con doble guión bajo al principio y al final de su nombre.** Estos métodos tienen un **comportamiento especial en Python** y se utilizan para implementar ciertas funcionalidades que no pueden ser realizadas mediante el uso de métodos normales.
#
# * Por ejemplo, el método mágico \__init__ se utiliza para inicializar una clase cuando se crea una nueva instancia de esa clase. Este método **se ejecuta automáticamente cuando se crea una nueva instancia de una clase** y se utiliza para establecer el estado inicial de la nueva instancia.

# %% [markdown]
# ### 4.1 Definiendo Métodos Mágicos
#
# * Para definir un método mágico en Python, se utiliza la sintaxis def __nombre_del_método__(self):.
#
# * El primer y último doble guión bajo es obligatorio y el nombre del método debe estar entre estos dos guiones bajos.
#
# * Además, todos los métodos mágicos **deben incluir el argumento self**, que se refiere a la instancia de la clase en la que se está ejecutando el método.
#
# Para utilizar un método mágico, simplemente **se lo llama como cualquier otro método,** pero utilizando la sintaxis especial que **incluye los dobles guiones** bajos al principio y al final del nombre del método.
#
# Algunos de estos métodos **se llaman de forma automática** cuando creamos un objeto o utilizamos alguna función de python.

# %% [markdown]
# ### 4.2 STR - Imprimiendo Objetos
#
# * Otro ejemplo de un método mágico es el método **\__str__**, que se **utiliza para representar una clase como una cadena de caracteres.**
#
# * Este método se llama automáticamente cuando **se intenta convertir una instancia de una clase en una cadena de caracteres,** por ejemplo mediante la llamada a la función str() o cuando se imprime una instancia de una clase utilizando la función print().

# %% [markdown]
# ### 4.3 Otros Métodos Mágicos
#
# Hay muchos otros métodos mágicos en Python, cada uno con una función específica. Algunos ejemplos de métodos mágicos son:
#
# * **\__add__:** se utiliza para sobrecargar el operador + y determinar cómo se sumarán dos instancias de una clase.
#
# * **\__len__:** se utiliza para determinar cuál es la longitud de una instancia de una clase.
#   * Por ejemplo, si se tiene una lista implementada mediante una clase y **se llama a la función len() sobre una instancia de esta clase,** se ejecutará el método **\__len__:** para determinar cuántos elementos hay en la lista.
#
#
# * **\__contains__:** se utiliza para determinar si una instancia de una clase **contiene un determinado elemento.**
#
#   * Por ejemplo, si se tiene una lista implementada mediante una clase y **se llama al operador in sobre una instancia de esta clase**, se ejecutará el método **\__contains__: para determinar si la lista contiene el elemento buscado.
#
#
# Hay muchos otros métodos mágicos en Python y cada uno de ellos se utiliza para implementar una funcionalidad específica. Para conocer todos los métodos mágicos disponibles en Python y su uso, se recomienda consultar la [documentación oficial de Python](https://docs.python.org/3/)

# %% [markdown]
# ---
# ## 5 ⭐**Esquema de una clase**⭐

# %% [markdown]
# ![esquema-de-una-clase-en-Python-1024x474.png](data:image/png;base64,...)

# %% [markdown]
# ---
# ## **Ejercicios y actividades para trabajar con clases**

# %% [markdown]
# ### **Ejercicio 1 - 😵 🤖 La Calculadora Humana 🤖😵**
#
# Desarrolla una clase que simule una calculadora. Dicha clase tendrá las caracteristicas y operaciones que describimos a continuación:
# 1. **Características/Atributos:**
#   * No tendrá ningún atributo.
#
# 2. **Operaciones/Métodos:**
#   * ➕**Sumar:**➕ realiza la suma de los dos números recibidos por parámetros.
#     * **Parámetros:**
#       * numero1: será un número decimal
#       * numero2: será un número decimal
#     * **Return:** Devuelve la suma de los dos números.
#   * ➖**Restar:**➖ realiza la resta de los dos números recibidos por parámetros.
#       * **Parámetros:**
#         * numero1: será un número decimal
#         * numero2: será un número decimal
#       * **Return:** Devuelve la resta del numero1 - numero2.
#   * ✖**Multiplicar:**✖ realiza la multiplicación de los dos números recibidos por parámetros.
#     * **Parámetros:**
#       * numero1: será un número decimal
#       * numero2: será un número decimal
#     * **Return:** Devuelve numero1 x numero2.
#   * ➗**Dividir:**➗ realiza la división de los dos números recibidos por parámetros. **Habrá que controlar que no se produzca un error al dividor por 0.**
#     * **Parámetros:**
#       * numero1: será un número decimal
#       * numero2: será un número decimal
#     * **Return:** Devuelve la división del numero1 entre numero2.
#   * **Menú:** Que hará lo siguiente:
#   1. Muestra un menú por pantalla con todas las operaciones que podrá realizar nuestra calculadora.
#   2. Leer la opción seleccionada por el usuario.
#   3. Realizará las siguientes acciones:
#     1. **Analizará** la opción que se ha seleccionado.
#     2. **Pedirá los números al usuario.**
#     3. **Llamará al método que corresponda.**
#     4. **Recogerá el resultado devuelvo por el método.**
#     5. **Mostrará el resultado en pantalla.**
#   4. Se permanecerá en el menú hasta que se pulse 5 (salir).
#   5. Cuando se pulse 5(salir), mostrará un mensaje de despedida y saldrá del menú.
#
#   6. El menú tendrá el siguiente aspecto:
#
# ![calculadora_humana.PNG](data:image/png;base64,...)
#
# 📘 **Una vez creada la clase. Se realizarán las siguientes acciones:** 📗
# 1. Crea/instancia un objeto Calculadora.
# 2. Llamar al método Menu.
# 3. Sumar dos números.
# 4. Restar un dos números positivos.
# 5. Multiplicar dos números.
# 6. Dividir 6 entre 4.
# 7. Dividir 6 entre 0. ¿Qué ocurre?

# %% [markdown]
# ### **Ejercicio 2 - 🧑 Clase Persona** 🧑
#
# Desarrolla la clase Persona. Para cada persona almacenaremos las siguientes características:
# * Nombre
# * Apellido 1
# * Apellido 2
# * DNI
# * Edad
#
# *Nota: Para inicializar el objeto, recuerda que tenemos el método especial __ init __*.
#
# Las operaciones que podrá realizar cada persona serán las siguientes:
#
# 1. **Presentarse.** Esta operación NO recibirá nada por parámetro.Mostrará en pantalla el texto: "Hola, encantado de conocerte, soy: "seguido del nombre de la persona.
#
#   Ejemplo:
#   Hola, encantado de conocerte soy: Saúl.
#
#   Return: no devolverá nada
#
# 2. **Saludar.** Esta operación NO recibirá nada por parámetro.Mostrará en pantalla el texto: "¡Hola! ¿Qué tal?".
#
#   Return: No devolverá nada
#
# 3. **Descansar.** Recibirá el parámetro Num_horas, que serán las horas que ha descansado la persona, **será un número entero.** Mostrará por pantalla un mensaje en función del valor de Num_horas:
#   * **Si Num_horas es > 9**, mostrará el mensaje: "He dormido como un lirón."
#   * **Si Num_horas es >= 6 y < 9**, mostrará el mensaje: "Qué bien he dormido"
#   * **Si Num_horas es < 6**, mostrará el mensaje: "No he pegado ojo!!"
#
#   Return: No devolverá nada
#
# 4. **Alimentarse.** Recibirá dos parámetros:
#
#   1. comida_del_dia: será una cadena de texto del tipo: "Desayuno", "Comida", "Merienda", "Cena", "Entre horas"
#   2. alimentos: será una lista de los alimentos que se ingieren en la comida. Por ejemplo: **["Galletas","Leche","Cucharada colacao","Avena","Zumo de naranja"]**
#   3. Mostrará un mensaje en pantalla indicando que ha realizado la comida y los alimentos que ha tomado.
#
#   Return: No devolverá nada
#
# 5. **Es_mayor_edad.** No recibirá parámetros.
#
#   Return: devolverá un **True** si la edad de la persona es >= 18 y **False** en caso contrario.
#
# 6. **Método especial __ str __** para mostrar los datos de la persona.
#
#   Return: devolverá una cadena de texto con los datos de la persona.
#
#
# 🤟**Una vez que tengas desarrollado todos los métodos. Lleva a cabo las siguientes acciones:**🤟
#
#
# 1. Crea/instancia dos personas con los siguientes datos:
#   * Persona1.
#     * Nombre: Agapito
#     * Apellido 1: Méndez
#     * Apellido 2: García
#     * Edad: 17
#     * DNI: 78987345P
#   * Persona2.
#     * Nombre: Ataulfa
#     * Apellido 1: Caballero
#     * Apellido 2: Pérez
#     * Edad: 21
#     * DNI: 23908345S
# 2. Utiliza el método **Presentarse** para las dos personas
# 3. Utiliza el método **Saludar** con la primera persona.
# 4. Imprime en pantalla los datos de las dos personas.
# 5. Utiliza el método **Es_mayor_edad** con ambas personas. Muestra en pantalla un mensaje en función del resultado devuelto por el método:
#   * Si el resultado devuelto es True, muestra **"Es mayor de edad."**
#   * Si el resultado es False, muestra **"No es mayor de edad"**.
# 6. Utiliza el método **Descansar** con todas las personas. La primerá descansará 12 horas y la segunda 4.
# 7. Utiliza el método **Alimentarse** con 1 persona en las 3 comidas principales del día, los alimentos que tomé podrás asignarselos a tu gusto.
#
# 8. Implementa algún método mágico que te permita:
#   * Mostrar los datos de un objeto persona
#   * Comparar dos personas por su edad.

# %% [markdown]
# ### **Ejercicio 3 - 📹🎮 NetFlix 📹🎮**
#
# Con los conocimientos adquiridos, desarrolla una aplicación que simule las altas/bajas de peliculas y socios de Netflix.
# Nuestro Netflix tendrá dos atributos:
# 1. Lista de socios.
# 2. Lista de peliculas.
#
# Será tarea tuya la creación de las clases socio y películas a tu gusto.

# %%
class Pelicula:
    def __init__(self, titulo, genero, anio, duracion, director):
        self.titulo = titulo
        self.genero = genero
        self.anio = anio
        self.duracion = duracion
        self.director = director

    def mostrar(self):
        return (f"Título: {self.titulo} | Género: {self.genero} | "
                f"Año: {self.anio} | Duración: {self.duracion} min | "
                f"Director: {self.director}")

    def esIgual(self, other):
        if isinstance(other, Pelicula):
            return self.titulo.lower() == other.titulo.lower()
        return False


class Socio:
    def __init__(self, nombre, apellidos, email):
        self.nombre = nombre
        self.apellidos = apellidos
        self.email = email

    def mostrar(self):
        return f"Nombre: {self.nombre} {self.apellidos} | Email: {self.email}"

    def esIgual(self, other):
        if isinstance(other, Socio):
            return self.email.lower() == other.email.lower()
        return False


class Netflix:
    def __init__(self):
        self.socios = []
        self.peliculas = []

    def darAltaSocio(self, socio):
        if socio in self.socios:
            print(f"El socio con email '{socio.email}' ya está registrado.")
        else:
            self.socios.append(socio)
            print(f"Socio '{socio.nombre} {socio.apellidos}' dado de alta correctamente.")

    def darBajaSocio(self, email):
        for socio in self.socios:
            if socio.email.lower() == email.lower():
                self.socios.remove(socio)
                print(f"Socio con email '{email}' dado de baja correctamente.")
                return
        print(f"No se encontró ningún socio con email '{email}'.")

    def darAltaPelicula(self, pelicula):
        if pelicula in self.peliculas:
            print(f"La película '{pelicula.titulo}' ya está en el catálogo.")
        else:
            self.peliculas.append(pelicula)
            print(f"Película '{pelicula.titulo}' añadida al catálogo correctamente.")

    def darBajaPelicula(self, titulo):
        for pelicula in self.peliculas:
            if pelicula.titulo.lower() == titulo.lower():
                self.peliculas.remove(pelicula)
                print(f"Película '{titulo}' eliminada del catálogo correctamente.")
                return
        print(f"No se encontró ninguna película con título '{titulo}'.")

    def listar_socios(self):
        if not self.socios:
            print("No hay socios registrados.")
        else:
            print("=== Lista de Socios ===")
            for i, socio in enumerate(self.socios, 1):
                print(f"  {i}. {socio}")

    def listar_peliculas(self):
        if not self.peliculas:
            print("No hay películas en el catálogo.")
        else:
            print("=== Catálogo de Películas ===")
            for i, pelicula in enumerate(self.peliculas, 1):
                print(f"  {i}. {pelicula}")

    def buscar_pelicula(self, titulo):
        for pelicula in self.peliculas:
            if pelicula.titulo.lower() == titulo.lower():
                print(f"Película encontrada: {pelicula}")
                return pelicula
        print(f"No se encontró ninguna película con título '{titulo}'.")
        return None

    def mostrar(self):
        return (f"Netflix | Socios: {len(self.socios)} | "
                f"Películas en catálogo: {len(self.peliculas)}")

# %%
# --- Instancia de Netflix ---
netflix = Netflix()

# --- Crear y añadir películas ---
p1 = Pelicula("El Padrino", "Drama/Crimen", 1972, 175, "Francis Ford Coppola")
p2 = Pelicula("Inception", "Ciencia Ficción", 2010, 148, "Christopher Nolan")
p3 = Pelicula("El Rey León", "Animación", 1994, 88, "Roger Allers")

netflix.alta_pelicula(p1)
netflix.alta_pelicula(p2)
netflix.alta_pelicula(p3)
netflix.alta_pelicula(p1)  # Intento de duplicado

print()

# --- Crear y añadir socios ---
s1 = Socio("Ana", "García López", "ana.garcia@email.com")
s2 = Socio("Carlos", "Martínez Ruiz", "carlos.martinez@email.com")
s3 = Socio("Laura", "Sánchez Pérez", "laura.sanchez@email.com")

netflix.alta_socio(s1)
netflix.alta_socio(s2)
netflix.alta_socio(s3)
netflix.alta_socio(s2)  # Intento de duplicado

print()

# --- Listar socios y películas ---
netflix.listar_socios()
print()
netflix.listar_peliculas()
print()

# --- Buscar una película ---
netflix.buscar_pelicula("Inception")
netflix.buscar_pelicula("Titanic")  # No existe
print()

# --- Dar de baja ---
netflix.baja_pelicula("El Rey León")
netflix.baja_socio("carlos.martinez@email.com")
netflix.baja_socio("noexiste@email.com")  # No existe
print()

# --- Listar de nuevo tras las bajas ---
netflix.listar_socios()
print()
netflix.listar_peliculas()
print()

# --- Resumen del estado de Netflix ---
print(netflix)
